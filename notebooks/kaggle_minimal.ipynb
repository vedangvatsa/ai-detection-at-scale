# %% [markdown]
# # Kaggle AI Detection: Minimal Working Notebook
#
# **Goal:** Download repo, assets, and run Binoculars baseline only.
#
# **Settings:** GPU T4 x2, Internet ON

# %%
# Install dependencies
# !pip install -q torch transformers tqdm pandas scikit-learn joblib

# %%
# Download repo as ZIP and extract
import os, zipfile, requests, sys
url = "https://github.com/vedangvatsa/ai-detection-at-scale/archive/refs/heads/main.zip"
r = requests.get(url)
open("repo.zip", "wb").write(r.content)
with zipfile.ZipFile("repo.zip") as z:
    z.extractall(".")
# !mv ai-detection-at-scale-main ai-detection-at-scale
# %cd ai-detection-at-scale
sys.path.insert(0, '.')
print("Repo ready")

# %%
# Download data/models from GitHub Releases
# !python scripts/download_assets.py

# %%
# Run Binoculars baseline only
MODEL = "gpt2"  # Change to "tiiuae/falcon-7b" for real comparison
# !python scripts/13_binoculars_baseline.py \
    --observer-model {MODEL} \
    --performer-model {MODEL} \
    --max-texts 2000

# %%
# Show results
import pandas as pd, os, glob
for f in glob.glob("results/*.csv"):
    print(f"\n=== {f} ===")
    try:
        print(pd.read_csv(f).to_string(index=False))
    except Exception as e:
        print(f"Could not read {f}: {e}")
# Copy to output
os.makedirs("/kaggle/working/output", exist_ok=True)
for f in glob.glob("results/*.csv"):
    # !cp {f} /kaggle/working/output/
print("\nResults saved to /kaggle/working/output")
